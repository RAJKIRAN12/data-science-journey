# %%
import pandas as pd 

df = pd.read_csv("data.csv")

print(df.describe())
print(df.info())
print(df.nunique())
print(df.isnull().sum())
# Out:
#              Age        Salary
# count  10.000000     10.000000
# mean   27.700000  55600.000000
# std     3.683296  10854.594521
# min    22.000000  41000.000000
# 25%    25.250000  47500.000000
# 50%    27.500000  54000.000000
# 75%    29.750000  62250.000000
# max    34.000000  75000.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         10 non-null     int64
#  2   Gender      10 non-null     object
#  3   Department  10 non-null     object
#  4   Salary      10 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes
# None
# Name          10
# Age           10
# Gender         2
# Department     4
# Salary        10
# dtype: int64
# Name          0
# Age           0
# Gender        0
# Department    0
# Salary        0
# dtype: int64

# %%
print(df['Gender'].value_counts())
print(df['Gender'].mode())
# Out:
# Gender
# Female    5
# Male      5
# Name: count, dtype: int64
# 0    Female
# 1      Male
# Name: Gender, dtype: object

# %%
# Fill missing with mean/median/mode
df['column'] = df['column'].fillna(df['column'].mean())

# Drop rows with missing values
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Fill missing with mean/median/mode
# ----> 2 df['column'] = df['column'].fillna(df['column'].mean())
#       4 # Drop rows with missing values
#       5 df = df.dropna()
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'column'

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Gender', 'Department', 'Salary'], dtype='object')

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())  # or use .median(), .mode()[0]

# %%
# Fill missing with mean/median/mode
df['column'] = df['column'].fillna(df['column'].mean())

# Drop rows with missing values
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Fill missing with mean/median/mode
# ----> 2 df['column'] = df['column'].fillna(df['column'].mean())
#       4 # Drop rows with missing values
#       5 df = df.dropna()
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'column'

# %%
corr = df.select_dtypes(include='number').corr()
print(corr)
# Out:
#              Age    Salary
# Age     1.000000  0.766481
# Salary  0.766481  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram
sns.histplot(df['Age'], kde=True)
plt.show()

# Boxplot
sns.boxplot(x='Gender', y='Age', data=df)
plt.show()

# Pairplot
sns.pairplot(df.select_dtypes(include='number'))
plt.show()

# Heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for 'age'
sns.histplot(df['Age'], kde=True)
plt.show()

# Boxplot
sns.boxplot(x=df['Age'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Histogram for 'age'
# ----> 5 sns.histplot(df['age'], kde=True)
#       6 plt.show()
#       8 # Boxplot
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'age'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for 'age'
sns.histplot(df['Salary'], kde=True)
plt.show()

# Boxplot
sns.boxplot(x=df['Salary'])
plt.show()
