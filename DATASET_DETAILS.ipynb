# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataset = pd.read_csv("C:\\Users\\rajkiran sapkota\\Downloads\\healthcare.csv")

dataset.head(3)
dataset["Age"].mean()
np.mean(dataset["Age"])
sns.histplot(x="Age", data=dataset, bins=[i for i in range(0,81,10)])
mn = np.mean(dataset["Age"])
sns.histplot(x="Age", data=dataset, bins=[i for i in range(0,81,10)])
plt.plot([mn for i in range(0,50)],[i for i in range(0,50)])
plt.show()
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Histogram of Age
sns.histplot(x="Age", data=dataset, bins=[i for i in range(0, 81, 10)])

# Let's say you calculated the mean age and want to plot a line
mn = dataset["Age"].mean()

# Add a vertical line for the mean
plt.axvline(mn, color='red', linestyle='--', label=f'Mean Age: {mn:.2f}')

# Show legend and plot
plt.legend()
plt.title("Age Distribution with Mean")
plt.show()

# %%
dataset.describe()
# Out:
#          PatientID         Age   Weight_kg   Height_cm  Glucose_mg_dL  \
# count   100.000000  100.000000  100.000000  100.000000     100.000000
# mean   1050.500000   52.870000   70.256000  165.705000      98.994000
# std      29.011492   21.901365   15.565244    9.370978      21.706085
# min    1001.000000   18.000000   35.200000  144.100000      45.200000
# 25%    1025.750000   32.000000   59.150000  159.575000      86.825000
# 50%    1050.500000   53.500000   70.600000  164.800000      96.650000
# 75%    1075.250000   71.250000   79.500000  171.000000     113.250000
# max    1100.000000   89.000000  115.900000  187.400000     155.700000
#
#        Hospital_Visits_Past_Year
# count                 100.000000
# mean                    4.640000
# std                     2.830284
# min                     0.000000
# 25%                     2.000000
# 50%                     5.000000
# 75%                     7.000000
# max                     9.000000
