# %%
name= "rajkiran"

# %%
age= 23

# %%
height= 5.7
is_student= True

# %%
print("name:", name)
print("age:", age)
print("height:", height)
print("Is Student?", is_student)
# Out:
# name: rajkiran
# age: 23
# height: 5.7
# Is Student? True

# %%
fruits= ["apple", "banana"]
print("First Fruit:", fruits[0])
# Out:
# First Fruit: apple

# %%
student = {
    "name": "Rajkiran",
    "age": 24,
    "course": "Data Science"
}
print("student's info:", student)
# Out:
# student's info: {'name': 'Rajkiran', 'age': 24, 'course': 'Data Science'}

# %%
coordinates= (10.0000, 20.0000)
print("coordinates are:", coordinates)
# Out:
# coordinates are: (10.0, 20.0)

# %%
score = 95

if score >= 90:
    print("Grade: A+")
elif score >= 80:
    print("Grade: B")
else:
    print("Grade: C or lower")
# Out:
# Grade: A+

# %%
for fruits in fruits:
    print("I like", fruits)
# Out:
# I like b
# I like a
# I like n
# I like a
# I like n
# I like a

# %%
count= 0
while count<=3:
    print("Counting:", count)
    count+=1
# Out:
# Counting: 0
# Counting: 1
# Counting: 2
# Counting: 3

# %%
def greet(name):
    return f"Hello, {name}!"
    
    print(greet("Rajkiran"))

    def add_numbers(a, b):
        return a+b

    print("Sum:", add_numbers(5, 10))

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Rajkiran"))

def add_numbers(a, b):
    return a + b

print("Sum:", add_numbers(5, 10))
# Out:
# Hello, Rajkiran!
# Sum: 15

# %%
def both_even(a, b):
    if a%2 == 0 and b%2 ==0:
        return True
    else:
        return False

# %%
print(both_even(2,4))
# Out:
# True

# %%
bio= {
    "name": " Hello Rajkiran,",
    "msg" : "You're",
    "age" : 24,
    "w" : "years old"
    
}

# %%
print("msg:", bio)
# Out:
# msg: {'name': ' Hello Rajkiran,', 'msg': "You're", 'age': 24, 'w': 'years old'}

# %%
# !git add .
# Out:
# ...
# ...
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> Acem_MIS_Major_project
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached Acem_MIS_Major_project
# hint:
# hint: See "git help submodule" for more information.
# ...
# error: open("AppData/Local/AMD/DxCache/00e8f431ffa3a715bf35d8f467a92dc0d908a246f25fffef.bin"): Permission denied
# error: unable to index file 'AppData/Local/AMD/DxCache/00e8f431ffa3a715bf35d8f467a92dc0d908a246f25fffef.bin'
# fatal: adding files failed

# %%
# !git commit -m "Day 1: Practiced basic functions and conditionals"
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.android/
# 	.bash_history
# 	.cache/
# 	.conda/
# 	.config/
# 	.crossnote/
# 	.dotnet/
# 	.emulator_console_auth_token
# 	.gitconfig
# 	.gk/
# 	.gradle/
# 	.idlerc/
# 	.ipynb_checkpoints/
# 	.ipython/
# 	.jupyter/
# 	.lesshst
# 	.lmmsrc.xml
# 	.m2/
# 	.matplotlib/
# 	.node_repl_history
# 	.packettracer
# 	.ssh/
# 	.th-client/
# 	.viminfo
# 	.vscode-R/
# 	.vscode/
# 	1pdf.pdf
# 	3D Objects/
# 	ARE.zip
# 	ARE/
# 	Acem_MIS_Major_project-ajay.zip
# 	Acem_MIS_Major_project/
# 	AndroidStudioProjects/
# 	AppData/
# 	Cisco Packet Tracer 8.2.1/
# 	Contacts/
# 	Creative Cloud Files Personal Account sapkotarajkiran@gmail.com 57367A4A62D23A7C0A495FA8@AdobeID/
# 	DAY1.ipynb
# 	Desktop/
# 	Documents/
# 	Downloads/
# 	Favorites/
# 	KANTIPUR-ONLINE-PORTAL.pptx
# 	KECReport.pdf
# 	Kantipur-online-portal.pdf
# 	LZW.c
# 	Links/
# 	Local Sites/
# 	MERN/
# 	Music/
# 	NCH Software Suite/
# 	NEWW/
# ...

# %%
# !git push origin main
# Out:
# To https://github.com/RAJKIRAN12/data-science-journey.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/RAJKIRAN12/data-science-journey.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
